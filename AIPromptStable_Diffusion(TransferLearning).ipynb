# %%
# !nvidia-smi --query-gpu=name,memory.total,memory.free --format=csv,noheader

# %%
#INSTALL REQUIREMENTS
# !wget -q https://github.com/ShivamShrirao/diffusers/raw/main/examples/dreambooth/train_dreambooth.py
# !wget -q https://github.com/ShivamShrirao/diffusers/raw/main/scripts/convert_diffusers_to_original_stable_diffusion.py
# %pip install -qq git+https://github.com/ShivamShrirao/diffusers
# %pip install -q -U --pre triton
# %pip install -q accelerate transformers ftfy bitsandbytes==0.35.0 gradio natsort safetensors xformers

# %%
#ADDING HUGGING FACE TOKEN
# !mkdir -p ~/.huggingface
HUGGINGFACE_TOKEN = "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" #@param {type:"string"}
# !echo -n "{HUGGINGFACE_TOKEN}" > ~/.huggingface/token

# %%
#USING MODEL
save_to_gdrive = True
if save_to_gdrive:
    from google.colab import drive
    drive.mount('/content/drive')

#@markdown Name/Path of the initial model.
MODEL_NAME = "runwayml/stable-diffusion-v1-5" #@param {type:"string"}

#@markdown Enter the directory name to save model at.

OUTPUT_DIR = "stable_diffusion_weights/zwx" #@param {type:"string"}
if save_to_gdrive:
    OUTPUT_DIR = "/content/drive/MyDrive/" + OUTPUT_DIR
else:
    OUTPUT_DIR = "/content/" + OUTPUT_DIR

print(f"[*] Weights will be saved at {OUTPUT_DIR}")

# !mkdir -p $OUTPUT_DIR

# %%
#USING PERSON OR DOG IMAGES
concepts_list = [
#    {
 #       "instance_prompt":      "photo of zwx dog",
 #       "class_prompt":         "photo of a dog",
  #      "instance_data_dir":    "/content/data/zwx",
#        "class_data_dir":       "/content/data/dog"
#    },
     {
         "instance_prompt":      "photo of ukj person",
        "class_prompt":         "photo of a person",
         "instance_data_dir":    "/content/data/ukj",
         "class_data_dir":       "/content/data/person"
     }
]

# `class_data_dir` contains regularization images
import json
import os
for c in concepts_list:
    os.makedirs(c["instance_data_dir"], exist_ok=True)

with open("concepts_list.json", "w") as f:
    json.dump(concepts_list, f, indent=4)

# %%
#UPLOADING YOUR IMAGES
import os
from google.colab import files
import shutil

for c in concepts_list:
    print(f"Uploading instance images for `{c['instance_prompt']}`")
    uploaded = files.upload()
    for filename in uploaded.keys():
        dst_path = os.path.join(c['instance_data_dir'], filename)
        shutil.move(filename, dst_path)

# %%
#TRAIN
# !python3 train_dreambooth.py \
  --pretrained_model_name_or_path=$MODEL_NAME \
  --pretrained_vae_name_or_path="stabilityai/sd-vae-ft-mse" \
  --output_dir=$OUTPUT_DIR \
  --revision="fp16" \
  --with_prior_preservation --prior_loss_weight=1.0 \
  --seed=1337 \
  --resolution=512 \
  --train_batch_size=1 \
  --train_text_encoder \
  --mixed_precision="fp16" \
  --use_8bit_adam \
  --gradient_accumulation_steps=1 \
  --learning_rate=1e-6 \
  --lr_scheduler="constant" \
  --lr_warmup_steps=0 \
  --num_class_images=50 \
  --sample_batch_size=4 \
  --max_train_steps=800 \
  --save_interval=10000 \
  --save_sample_prompt="photo of zwx dog" \
  --concepts_list="concepts_list.json"
# Out:
# ===================================BUG REPORT===================================
# Welcome to bitsandbytes. For bug reports, please submit your error trace to: https://github.com/TimDettmers/bitsandbytes/issues
# For effortless bug reporting copy-paste your error into this form: https://docs.google.com/forms/d/e/1FAIpQLScPB8emS3Thkp66nvqwmjTEgxp8Y9ufuWTzFyr9kJ5AoI47dQ/viewform?usp=sf_link
# ================================================================================
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/paths.py:105: UserWarning: /usr/lib64-nvidia did not contain libcudart.so as expected! Searching further paths...
#   warn(
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/paths.py:27: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('/sys/fs/cgroup/memory.events /var/colab/cgroup/jupyter-children/memory.events')}
#   warn(
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/paths.py:27: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('http'), PosixPath('//172.28.0.1'), PosixPath('8013')}
#   warn(
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/paths.py:27: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('--logtostderr --listen_host=172.28.0.12 --target_host=172.28.0.12 --tunnel_background_save_url=https'), PosixPath('//colab.research.google.com/tun/m/cc48301118ce562b961b3c22d803539adc1e0c19/gpu-t4-s-2wvfdl5a3dg3e --tunnel_background_save_delay=10s --tunnel_periodic_background_save_frequency=30m0s --enable_output_coalescing=true --output_coalescing_required=true')}
#   warn(
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/paths.py:27: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('/env/python')}
#   warn(
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/paths.py:27: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('//ipykernel.pylab.backend_inline'), PosixPath('module')}
#   warn(
# CUDA_SETUP: WARNING! libcudart.so not found in any environmental path. Searching /usr/local/cuda/lib64...
# CUDA SETUP: CUDA runtime path found: /usr/local/cuda/lib64/libcudart.so
# CUDA SETUP: Highest compute capability among GPUs detected: 7.5
# CUDA SETUP: Detected CUDA version 118
# CUDA SETUP: Loading binary /usr/local/lib/python3.10/dist-packages/bitsandbytes/libbitsandbytes_cuda118.so...
# 2023-09-25 10:34:36.870917: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_hf_folder.py:98: UserWarning: A token has been found in `/root/.huggingface/token`. This is the old path where tokens were stored. The new location is `/root/.cache/huggingface/token` which is configurable using `HF_HOME` environment variable. Your token has been copied to this new location. You can now safely delete the old token file manually or use `huggingface-cli logout`.
#   warnings.warn(
# Downloading (…)lve/main/config.json: 100% 547/547 [00:00<00:00, 2.73MB/s]
# Downloading (…)ch_model.safetensors: 100% 335M/335M [00:04<00:00, 78.5MB/s]
# Downloading (…)p16/model_index.json: 100% 543/543 [00:00<00:00, 2.56MB/s]
# safety_checker/model.safetensors not found
# Fetching 15 files:   0% 0/15 [00:00<?, ?it/s]
# Downloading (…)cheduler_config.json: 100% 307/307 [00:00<00:00, 1.12MB/s]
#
# Downloading (…)rocessor_config.json: 100% 342/342 [00:00<00:00, 1.92MB/s]
# Fetching 15 files:   7% 1/15 [00:01<00:16,  1.21s/it]
# Downloading (…)_checker/config.json: 100% 4.70k/4.70k [00:00<00:00, 23.5MB/s]
#
# Downloading (…)_encoder/config.json: 100% 636/636 [00:00<00:00, 3.41MB/s]
#
# Downloading (…)tokenizer/merges.txt: 100% 525k/525k [00:00<00:00, 7.49MB/s]
#
# Downloading (…)tokenizer/vocab.json:   0% 0.00/1.06M [00:00<?, ?B/s]
#
# Downloading (…)cc2/unet/config.json: 100% 806/806 [00:00<00:00, 3.63MB/s]
#
#
# Downloading pytorch_model.bin:   0% 0.00/246M [00:00<?, ?B/s]
#
#
# Downloading (…)cial_tokens_map.json: 100% 472/472 [00:00<00:00, 2.70MB/s]
#
#
#
# Downloading (…)9cc2/vae/config.json: 100% 609/609 [00:00<00:00, 3.20MB/s]
#
#
#
# Downloading (…)okenizer_config.json: 100% 822/822 [00:00<00:00, 5.53MB/s]
#
#
#
# Downloading pytorch_model.bin:   0% 0.00/608M [00:00<?, ?B/s]
#
#
# Downloading pytorch_model.bin:   2% 10.5M/608M [00:00<00:08, 74.6MB/s]
# Downloading (…)tokenizer/vocab.json: 100% 1.06M/1.06M [00:00<00:00, 3.81MB/s]
#
# Downloading (…)on_pytorch_model.bin:   0% 0.00/1.72G [00:00<?, ?B/s]
#
# Downloading pytorch_model.bin:   4% 10.5M/246M [00:00<00:05, 41.2MB/s]
#
#
# Downloading pytorch_model.bin:   5% 31.5M/608M [00:00<00:05, 106MB/s]
#
# Downloading pytorch_model.bin:   9% 21.0M/246M [00:00<00:03, 61.2MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:   0% 0.00/167M [00:00<?, ?B/s]
# Downloading (…)on_pytorch_model.bin:   1% 10.5M/1.72G [00:00<00:39, 43.4MB/s]
#
# Downloading pytorch_model.bin:  17% 41.9M/246M [00:00<00:02, 85.0MB/s]
#
#
# Downloading pytorch_model.bin:   9% 52.4M/608M [00:00<00:05, 101MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:   6% 10.5M/167M [00:00<00:02, 57.3MB/s]
# Downloading (…)on_pytorch_model.bin:   1% 21.0M/1.72G [00:00<00:30, 56.5MB/s]
#
#
# Downloading pytorch_model.bin:  10% 62.9M/608M [00:00<00:05, 97.5MB/s]
# Downloading (…)on_pytorch_model.bin:   2% 31.5M/1.72G [00:00<00:24, 69.0MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  13% 21.0M/167M [00:00<00:02, 68.6MB/s]
#
# Downloading pytorch_model.bin:  26% 62.9M/246M [00:00<00:01, 96.0MB/s]
#
#
# Downloading pytorch_model.bin:  12% 73.4M/608M [00:00<00:05, 95.5MB/s]
# Downloading (…)on_pytorch_model.bin:   2% 41.9M/1.72G [00:00<00:21, 79.1MB/s]
#
# Downloading pytorch_model.bin:  30% 73.4M/246M [00:00<00:01, 97.2MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  25% 41.9M/167M [00:00<00:01, 89.2MB/s]
# Downloading (…)on_pytorch_model.bin:   3% 52.4M/1.72G [00:00<00:19, 85.8MB/s]
#
#
# Downloading pytorch_model.bin:  16% 94.4M/608M [00:00<00:04, 107MB/s]
#
# Downloading pytorch_model.bin:  38% 94.4M/246M [00:01<00:01, 103MB/s]
# Downloading (…)on_pytorch_model.bin:   4% 62.9M/1.72G [00:00<00:19, 86.0MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  38% 62.9M/167M [00:00<00:01, 101MB/s]
#
#
# Downloading pytorch_model.bin:  19% 115M/608M [00:01<00:04, 119MB/s]
#
# Downloading pytorch_model.bin:  43% 105M/246M [00:01<00:01, 102MB/s]
# Downloading (…)on_pytorch_model.bin:   5% 83.9M/1.72G [00:01<00:16, 96.4MB/s]
#
# Downloading pytorch_model.bin:  47% 115M/246M [00:01<00:01, 99.8MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  50% 83.9M/167M [00:00<00:00, 106MB/s]
#
#
# Downloading pytorch_model.bin:  22% 136M/608M [00:01<00:04, 102MB/s]
# Downloading (…)on_pytorch_model.bin:   5% 94.4M/1.72G [00:01<00:18, 89.3MB/s]
#
# Downloading pytorch_model.bin:  51% 126M/246M [00:01<00:01, 88.8MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  56% 94.4M/167M [00:01<00:00, 96.7MB/s]
# Downloading (…)on_pytorch_model.bin:   6% 105M/1.72G [00:01<00:20, 79.3MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  63% 105M/167M [00:01<00:00, 77.9MB/s]
#
# Downloading pytorch_model.bin:  55% 136M/246M [00:01<00:01, 67.8MB/s]
# Downloading (…)on_pytorch_model.bin:   7% 115M/1.72G [00:01<00:22, 72.4MB/s]
#
#
# Downloading pytorch_model.bin:  26% 157M/608M [00:01<00:05, 77.8MB/s]
#
# Downloading pytorch_model.bin:  60% 147M/246M [00:01<00:01, 68.5MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  69% 115M/167M [00:01<00:00, 65.4MB/s]
# Downloading (…)on_pytorch_model.bin:   7% 126M/1.72G [00:01<00:24, 65.5MB/s]
#
#
# Downloading pytorch_model.bin:  28% 168M/608M [00:01<00:06, 71.6MB/s]
#
# Downloading pytorch_model.bin:  64% 157M/246M [00:01<00:01, 68.7MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  75% 126M/167M [00:01<00:00, 66.6MB/s]
# Downloading (…)on_pytorch_model.bin:   8% 136M/1.72G [00:01<00:21, 72.4MB/s]
#
# Downloading pytorch_model.bin:  68% 168M/246M [00:02<00:01, 66.4MB/s]
#
#
# Downloading pytorch_model.bin:  29% 178M/608M [00:02<00:06, 66.8MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  81% 136M/167M [00:01<00:00, 65.1MB/s]
# Downloading (…)on_pytorch_model.bin:   9% 147M/1.72G [00:02<00:23, 65.9MB/s]
#
# Downloading pytorch_model.bin:  72% 178M/246M [00:02<00:00, 70.6MB/s]
#
#
# Downloading pytorch_model.bin:  31% 189M/608M [00:02<00:06, 68.5MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  88% 147M/167M [00:02<00:00, 57.8MB/s]
# Downloading (…)on_pytorch_model.bin:   9% 157M/1.72G [00:02<00:26, 58.5MB/s]
#
# Downloading pytorch_model.bin:  77% 189M/246M [00:02<00:00, 64.4MB/s]
#
#
# Downloading pytorch_model.bin:  33% 199M/608M [00:02<00:06, 65.3MB/s]
#
# Downloading pytorch_model.bin:  81% 199M/246M [00:02<00:00, 66.5MB/s]
#
#
# Downloading pytorch_model.bin:  34% 210M/608M [00:02<00:06, 64.5MB/s]
# Downloading (…)on_pytorch_model.bin:  10% 168M/1.72G [00:02<00:27, 55.7MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin: 100% 167M/167M [00:02<00:00, 66.2MB/s]
#
# Downloading pytorch_model.bin:  85% 210M/246M [00:02<00:00, 69.3MB/s]
#
#
# Downloading (…)on_pytorch_model.bin: 100% 167M/167M [00:02<00:00, 69.7MB/s]
#
# Downloading (…)on_pytorch_model.bin:  10% 178M/1.72G [00:02<00:26, 57.2MB/s]
#
# Downloading pytorch_model.bin:  89% 220M/246M [00:02<00:00, 68.5MB/s]
#
#
# Downloading pytorch_model.bin:  38% 231M/608M [00:02<00:05, 70.4MB/s]
# Downloading (…)on_pytorch_model.bin:  11% 189M/1.72G [00:02<00:23, 65.5MB/s]
#
# Downloading pytorch_model.bin:  94% 231M/246M [00:03<00:00, 71.4MB/s]
#
#
# Downloading pytorch_model.bin:  40% 241M/608M [00:03<00:05, 71.4MB/s]
# Downloading (…)on_pytorch_model.bin:  12% 199M/1.72G [00:02<00:23, 65.3MB/s]
#
# Downloading pytorch_model.bin:  98% 241M/246M [00:03<00:00, 69.3MB/s]
#
#
# Downloading pytorch_model.bin:  41% 252M/608M [00:03<00:05, 63.3MB/s]
# Downloading (…)on_pytorch_model.bin:  12% 210M/1.72G [00:03<00:24, 61.1MB/s]
#
#
# Downloading pytorch_model.bin: 100% 246M/246M [00:03<00:00, 69.3MB/s]
#
# Downloading (…)on_pytorch_model.bin:  13% 220M/1.72G [00:03<00:28, 51.8MB/s]
# Downloading (…)on_pytorch_model.bin:  13% 231M/1.72G [00:03<00:25, 59.2MB/s]
#
#
# Downloading pytorch_model.bin:  45% 273M/608M [00:03<00:05, 57.1MB/s]
#
#
# Downloading pytorch_model.bin:  48% 294M/608M [00:03<00:04, 76.5MB/s]
# Downloading (…)on_pytorch_model.bin:  15% 262M/1.72G [00:03<00:15, 92.4MB/s]
#
#
# Downloading pytorch_model.bin:  50% 304M/608M [00:03<00:04, 73.5MB/s]
# Downloading (…)on_pytorch_model.bin:  16% 283M/1.72G [00:03<00:14, 100MB/s]
#
#
# Downloading pytorch_model.bin:  53% 325M/608M [00:04<00:02, 100MB/s]
# Downloading (…)on_pytorch_model.bin:  18% 304M/1.72G [00:03<00:12, 115MB/s]
#
#
# Downloading pytorch_model.bin:  59% 357M/608M [00:04<00:01, 136MB/s]
# Downloading (…)on_pytorch_model.bin:  19% 325M/1.72G [00:04<00:10, 130MB/s]
#
#
# Downloading pytorch_model.bin:  64% 388M/608M [00:04<00:01, 164MB/s]
# Downloading (…)on_pytorch_model.bin:  20% 346M/1.72G [00:04<00:09, 142MB/s]
#
#
# Downloading pytorch_model.bin:  67% 409M/608M [00:04<00:01, 170MB/s]
# Downloading (…)on_pytorch_model.bin:  21% 367M/1.72G [00:04<00:08, 152MB/s]
# Downloading (…)on_pytorch_model.bin:  23% 388M/1.72G [00:04<00:08, 153MB/s]
#
#
# Downloading pytorch_model.bin:  71% 430M/608M [00:04<00:01, 150MB/s]
# Downloading (…)on_pytorch_model.bin:  24% 409M/1.72G [00:04<00:08, 157MB/s]
#
#
# Downloading pytorch_model.bin:  74% 451M/608M [00:04<00:01, 138MB/s]
# Downloading (…)on_pytorch_model.bin:  25% 430M/1.72G [00:04<00:09, 136MB/s]
#
#
# Downloading pytorch_model.bin:  78% 472M/608M [00:04<00:01, 136MB/s]
# Downloading (…)on_pytorch_model.bin:  26% 451M/1.72G [00:04<00:09, 139MB/s]
#
#
# Downloading pytorch_model.bin:  81% 493M/608M [00:05<00:00, 132MB/s]
# Downloading (…)on_pytorch_model.bin:  27% 472M/1.72G [00:05<00:09, 134MB/s]
#
#
# Downloading pytorch_model.bin:  84% 514M/608M [00:05<00:00, 132MB/s]
# Downloading (…)on_pytorch_model.bin:  29% 493M/1.72G [00:05<00:09, 130MB/s]
#
#
# Downloading pytorch_model.bin:  88% 535M/608M [00:05<00:00, 127MB/s]
# Downloading (…)on_pytorch_model.bin:  30% 514M/1.72G [00:05<00:09, 131MB/s]
#
#
# Downloading pytorch_model.bin:  91% 556M/608M [00:05<00:00, 126MB/s]
# Downloading (…)on_pytorch_model.bin:  31% 535M/1.72G [00:05<00:09, 124MB/s]
#
#
# Downloading pytorch_model.bin:  95% 577M/608M [00:05<00:00, 132MB/s]
# Downloading (…)on_pytorch_model.bin:  32% 556M/1.72G [00:05<00:09, 123MB/s]
#
#
# Downloading pytorch_model.bin:  98% 598M/608M [00:05<00:00, 130MB/s]
# Downloading pytorch_model.bin: 100% 608M/608M [00:06<00:00, 99.4MB/s]
# Fetching 15 files:  27% 4/15 [00:07<00:21,  1.96s/it]
# Downloading (…)on_pytorch_model.bin:  35% 598M/1.72G [00:06<00:08, 139MB/s]
# Downloading (…)on_pytorch_model.bin:  37% 629M/1.72G [00:06<00:07, 150MB/s]
# Downloading (…)on_pytorch_model.bin:  38% 661M/1.72G [00:06<00:06, 176MB/s]
# Downloading (…)on_pytorch_model.bin:  40% 692M/1.72G [00:06<00:05, 201MB/s]
# Downloading (…)on_pytorch_model.bin:  42% 724M/1.72G [00:06<00:04, 222MB/s]
# Downloading (…)on_pytorch_model.bin:  44% 755M/1.72G [00:06<00:04, 236MB/s]
# Downloading (…)on_pytorch_model.bin:  46% 786M/1.72G [00:06<00:03, 242MB/s]
# Downloading (…)on_pytorch_model.bin:  48% 818M/1.72G [00:06<00:03, 247MB/s]
# Downloading (…)on_pytorch_model.bin:  49% 849M/1.72G [00:07<00:03, 256MB/s]
# Downloading (…)on_pytorch_model.bin:  51% 881M/1.72G [00:07<00:03, 251MB/s]
# Downloading (…)on_pytorch_model.bin:  53% 912M/1.72G [00:07<00:03, 259MB/s]
# Downloading (…)on_pytorch_model.bin:  55% 944M/1.72G [00:07<00:03, 254MB/s]
# Downloading (…)on_pytorch_model.bin:  57% 975M/1.72G [00:07<00:02, 258MB/s]
# Downloading (…)on_pytorch_model.bin:  59% 1.01G/1.72G [00:07<00:02, 263MB/s]
# Downloading (…)on_pytorch_model.bin:  60% 1.04G/1.72G [00:07<00:02, 244MB/s]
# Downloading (…)on_pytorch_model.bin:  62% 1.07G/1.72G [00:08<00:03, 172MB/s]
# Downloading (…)on_pytorch_model.bin:  63% 1.09G/1.72G [00:08<00:03, 171MB/s]
# Downloading (…)on_pytorch_model.bin:  65% 1.11G/1.72G [00:08<00:03, 176MB/s]
# Downloading (…)on_pytorch_model.bin:  66% 1.14G/1.72G [00:08<00:02, 206MB/s]
# Downloading (…)on_pytorch_model.bin:  68% 1.17G/1.72G [00:08<00:02, 217MB/s]
# Downloading (…)on_pytorch_model.bin:  70% 1.21G/1.72G [00:08<00:02, 220MB/s]
# Downloading (…)on_pytorch_model.bin:  72% 1.24G/1.72G [00:08<00:02, 220MB/s]
# Downloading (…)on_pytorch_model.bin:  74% 1.27G/1.72G [00:09<00:02, 225MB/s]
# Downloading (…)on_pytorch_model.bin:  76% 1.30G/1.72G [00:09<00:01, 231MB/s]
# Downloading (…)on_pytorch_model.bin:  77% 1.33G/1.72G [00:09<00:01, 241MB/s]
# Downloading (…)on_pytorch_model.bin:  79% 1.36G/1.72G [00:09<00:01, 250MB/s]
# Downloading (…)on_pytorch_model.bin:  81% 1.39G/1.72G [00:09<00:01, 248MB/s]
# Downloading (…)on_pytorch_model.bin:  83% 1.43G/1.72G [00:09<00:01, 249MB/s]
# Downloading (…)on_pytorch_model.bin:  85% 1.46G/1.72G [00:09<00:01, 256MB/s]
# Downloading (…)on_pytorch_model.bin:  87% 1.49G/1.72G [00:09<00:00, 251MB/s]
# Downloading (…)on_pytorch_model.bin:  88% 1.52G/1.72G [00:09<00:00, 257MB/s]
# Downloading (…)on_pytorch_model.bin:  90% 1.55G/1.72G [00:10<00:00, 253MB/s]
# Downloading (…)on_pytorch_model.bin:  92% 1.58G/1.72G [00:10<00:00, 255MB/s]
# Downloading (…)on_pytorch_model.bin:  94% 1.61G/1.72G [00:10<00:00, 260MB/s]
# Downloading (…)on_pytorch_model.bin:  96% 1.65G/1.72G [00:10<00:00, 247MB/s]
# Downloading (…)on_pytorch_model.bin:  98% 1.68G/1.72G [00:10<00:00, 235MB/s]
# Downloading (…)on_pytorch_model.bin: 100% 1.72G/1.72G [00:11<00:00, 156MB/s]
# Fetching 15 files: 100% 15/15 [00:12<00:00,  1.18it/s]
# /usr/local/lib/python3.10/dist-packages/transformers/models/clip/feature_extraction_clip.py:28: FutureWarning: The class CLIPFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use CLIPImageProcessor instead.
#   warnings.warn(
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
# 09/25/2023 10:35:10 - INFO - __main__ - Number of class images to sample: 50.
# Generating class images: 100% 13/13 [02:46<00:00, 12.85s/it]
# /usr/local/lib/python3.10/dist-packages/diffusers/configuration_utils.py:203: FutureWarning: It is deprecated to pass a pretrained model name or path to `from_config`.If you were trying to load a scheduler, please use <class 'diffusers.schedulers.scheduling_ddpm.DDPMScheduler'>.from_pretrained(...) instead. Otherwise, please make sure to pass a configuration dictionary instead. This functionality will be removed in v1.0.0.
#   deprecate("config-passed-as-path", "1.0.0", deprecation_message, standard_warn=False)
# Downloading (…)cheduler_config.json: 100% 308/308 [00:00<00:00, 1.75MB/s]
# Caching latents: 100% 50/50 [00:09<00:00,  5.22it/s]
# 09/25/2023 10:38:26 - INFO - __main__ - ***** Running training *****
# 09/25/2023 10:38:26 - INFO - __main__ -   Num examples = 50
# 09/25/2023 10:38:26 - INFO - __main__ -   Num batches each epoch = 50
# 09/25/2023 10:38:26 - INFO - __main__ -   Num Epochs = 16
# 09/25/2023 10:38:26 - INFO - __main__ -   Instantaneous batch size per device = 1
# 09/25/2023 10:38:26 - INFO - __main__ -   Total train batch size (w. parallel, distributed & accumulation) = 1
# 09/25/2023 10:38:26 - INFO - __main__ -   Gradient Accumulation steps = 1
# 09/25/2023 10:38:26 - INFO - __main__ -   Total optimization steps = 800
# Steps: 100% 800/800 [09:28<00:00,  1.42it/s, loss=0.249, lr=1e-6]safety_checker/model.safetensors not found
# /usr/local/lib/python3.10/dist-packages/transformers/models/clip/feature_extraction_clip.py:28: FutureWarning: The class CLIPFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use CLIPImageProcessor instead.
#   warnings.warn(
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
#
# Generating samples:   0% 0/4 [00:00<?, ?it/s]
# Generating samples:  25% 1/4 [00:05<00:16,  5.37s/it]
# Generating samples:  50% 2/4 [00:09<00:09,  4.59s/it]
# Generating samples:  75% 3/4 [00:13<00:04,  4.23s/it]
# Generating samples: 100% 4/4 [00:17<00:00,  4.25s/it]
# [*] Weights saved at /content/drive/MyDrive/stable_diffusion_weights/zwx/800
# Steps: 100% 800/800 [12:14<00:00,  1.09it/s, loss=0.249, lr=1e-6]

# %%
#Specify the weights directory to use (leave blank for latest)
WEIGHTS_DIR = ""
if WEIGHTS_DIR == "":
    from natsort import natsorted
    from glob import glob
    import os
    WEIGHTS_DIR = natsorted(glob(OUTPUT_DIR + os.sep + "*"))[-1]
print(f"[*] WEIGHTS_DIR={WEIGHTS_DIR}")

# %%
#Run to generate a grid of preview images from the last saved weights.
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

weights_folder = OUTPUT_DIR
folders = sorted([f for f in os.listdir(weights_folder) if f != "0"], key=lambda x: int(x))

row = len(folders)
col = len(os.listdir(os.path.join(weights_folder, folders[0], "samples")))
scale = 4
fig, axes = plt.subplots(row, col, figsize=(col*scale, row*scale), gridspec_kw={'hspace': 0, 'wspace': 0})

for i, folder in enumerate(folders):
    folder_path = os.path.join(weights_folder, folder)
    image_folder = os.path.join(folder_path, "samples")
    images = [f for f in os.listdir(image_folder)]
    for j, image in enumerate(images):
        if row == 1:
            currAxes = axes[j]
        else:
            currAxes = axes[i, j]
        if i == 0:
            currAxes.set_title(f"Image {j}")
        if j == 0:
            currAxes.text(-0.1, 0.5, folder, rotation=0, va='center', ha='center', transform=currAxes.transAxes)
        image_path = os.path.join(image_folder, image)
        img = mpimg.imread(image_path)
        currAxes.imshow(img, cmap='gray')
        currAxes.axis('off')

plt.tight_layout()
plt.savefig('grid.png', dpi=72)

# %%
#RUN CONVERSION
ckpt_path = WEIGHTS_DIR + "/model.ckpt"

half_arg = ""

fp16 = True
if fp16:
    half_arg = "--half"
# !python convert_diffusers_to_original_stable_diffusion.py --model_path $WEIGHTS_DIR  --checkpoint_path $ckpt_path $half_arg
print(f"[*] Converted ckpt saved at {ckpt_path}")
# Out:
# Reshaping encoder.mid.attn_1.q.weight for SD format
# Reshaping encoder.mid.attn_1.k.weight for SD format
# Reshaping encoder.mid.attn_1.v.weight for SD format
# Reshaping encoder.mid.attn_1.proj_out.weight for SD format
# Reshaping decoder.mid.attn_1.q.weight for SD format
# Reshaping decoder.mid.attn_1.k.weight for SD format
# Reshaping decoder.mid.attn_1.v.weight for SD format
# Reshaping decoder.mid.attn_1.proj_out.weight for SD format
# Traceback (most recent call last):
#   File "/content/convert_diffusers_to_original_stable_diffusion.py", line 333, in <module>
#     torch.save(state_dict, args.checkpoint_path)
#   File "/usr/local/lib/python3.10/dist-packages/torch/serialization.py", line 441, in save
#     _save(obj, opened_zipfile, pickle_module, pickle_protocol)
#   File "/usr/local/lib/python3.10/dist-packages/torch/serialization.py", line 668, in _save
#     zip_file.write_record(name, storage.data_ptr(), num_bytes)
# KeyboardInterrupt
# ^C
# [*] Converted ckpt saved at /content/drive/MyDrive/stable_diffusion_weights/zwx/800/model.ckpt

# %%
 #If you want to use previously trained model saved in gdrive, replace this with the full path of model in gdrive
import torch
from torch import autocast
from diffusers import StableDiffusionPipeline, DDIMScheduler
from IPython.display import display

model_path = WEIGHTS_DIR
pipe = StableDiffusionPipeline.from_pretrained(model_path, safety_checker=None, torch_dtype=torch.float16).to("cuda")
pipe.scheduler = DDIMScheduler.from_config(pipe.scheduler.config)
pipe.enable_xformers_memory_efficient_attention()
g_cuda = None
# Out:
# ===================================BUG REPORT===================================
# Welcome to bitsandbytes. For bug reports, please submit your error trace to: https://github.com/TimDettmers/bitsandbytes/issues
# For effortless bug reporting copy-paste your error into this form: https://docs.google.com/forms/d/e/1FAIpQLScPB8emS3Thkp66nvqwmjTEgxp8Y9ufuWTzFyr9kJ5AoI47dQ/viewform?usp=sf_link
# ================================================================================
# CUDA_SETUP: WARNING! libcudart.so not found in any environmental path. Searching /usr/local/cuda/lib64...
# CUDA SETUP: CUDA runtime path found: /usr/local/cuda/lib64/libcudart.so
# CUDA SETUP: Highest compute capability among GPUs detected: 7.5
# CUDA SETUP: Detected CUDA version 118
# CUDA SETUP: Loading binary /usr/local/lib/python3.10/dist-packages/bitsandbytes/libbitsandbytes_cuda118.so...
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/paths.py:105: UserWarning: /usr/lib64-nvidia did not contain libcudart.so as expected! Searching further paths...
#   warn(
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/paths.py:27: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('/sys/fs/cgroup/memory.events /var/colab/cgroup/jupyter-children/memory.events')}
#   warn(
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/paths.py:27: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('http'), PosixPath('//172.28.0.1'), PosixPath('8013')}
#   warn(
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/paths.py:27: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('//colab.research.google.com/tun/m/cc48301118ce562b961b3c22d803539adc1e0c19/gpu-t4-s-2wvfdl5a3dg3e --tunnel_background_save_delay=10s --tunnel_periodic_background_save_frequency=30m0s --enable_output_coalescing=true --output_coalescing_required=true'), PosixPath('--logtostderr --listen_host=172.28.0.12 --target_host=172.28.0.12 --tunnel_background_save_url=https')}
#   warn(
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/paths.py:27: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('/env/python')}
#   warn(
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/paths.py:27: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('module'), PosixPath('//ipykernel.pylab.backend_inline')}
#   warn(
# /usr/local/lib/python3.10/dist-packages/transformers/models/clip/feature_extraction_clip.py:28: FutureWarning: The class CLIPFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use CLIPImageProcessor instead.
#   warnings.warn(
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .

# %%
#Can set random seed here for reproducibility.
g_cuda = torch.Generator(device='cuda')
seed = 52362
g_cuda.manual_seed(seed)

# %%
#Run for generating images.

prompt = "\"magical ocean goddess ukj\", water, spray, waves, flowing hair, head and shoulders portrait, finely drawn eyes, 8k resolution concept art portrait dynamic lighting hyperdetailed intricately detailed Splash art trending on Artstation Unreal Engine 5 volumetric lighting" #@param {type:"string"}
negative_prompt = ""
num_samples = 4
guidance_scale = 7.5
num_inference_steps = 24 #
height = 512
width = 512

with autocast("cuda"), torch.inference_mode():
    images = pipe(
        prompt,
        height=height,
        width=width,
        negative_prompt=negative_prompt,
        num_images_per_prompt=num_samples,
        num_inference_steps=num_inference_steps,
        guidance_scale=guidance_scale,
        generator=g_cuda
    ).images

for img in images:
    display(img)
# Out:
#   0%|          | 0/24 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>
# <PIL.Image.Image image mode=RGB size=512x512>
# <PIL.Image.Image image mode=RGB size=512x512>
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
#@markdown Run Gradio UI for generating images.
import gradio as gr

def inference(prompt, negative_prompt, num_samples, height=512, width=512, num_inference_steps=50, guidance_scale=7.5):
    with torch.autocast("cuda"), torch.inference_mode():
        return pipe(
                prompt, height=int(height), width=int(width),
                negative_prompt=negative_prompt,
                num_images_per_prompt=int(num_samples),
                num_inference_steps=int(num_inference_steps), guidance_scale=guidance_scale,
                generator=g_cuda
            ).images

with gr.Blocks() as demo:
    with gr.Row():
        with gr.Column():
            prompt = gr.Textbox(label="Prompt", value="photo of zwx dog in a bucket")
            negative_prompt = gr.Textbox(label="Negative Prompt", value="")
            run = gr.Button(value="Generate")
            with gr.Row():
                num_samples = gr.Number(label="Number of Samples", value=4)
                guidance_scale = gr.Number(label="Guidance Scale", value=7.5)
            with gr.Row():
                height = gr.Number(label="Height", value=512)
                width = gr.Number(label="Width", value=512)
            num_inference_steps = gr.Slider(label="Steps", value=24)
        with gr.Column():
            gallery = gr.Gallery()

    run.click(inference, inputs=[prompt, negative_prompt, num_samples, height, width, num_inference_steps, guidance_scale], outputs=gallery)

demo.launch(debug=True)

# %%
# Free runtime memory
exit()
